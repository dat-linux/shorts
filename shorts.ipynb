# %% [markdown]
# <div id="topshorts" style="float:left"> <table>
# <tr>
#     <td style="font-weight:bold;">Short positions</td>
#     <td><button data-commandLinker-command="notebook:run-all-below" href="#">RUN</button></td>
#     <td><button data-commandLinker-command="notebook:clear-all-cell-outputs" href="#">CLEAR</button></td>
# <tr>
# </table>
# </div>

# %%
# %run src/shorts.ipy
# Out:
# HTML(value='Short positions as of: <b>13-06-2023')
# Accordion(children=(HBox(children=(Text(value='', description='Filter: ', placeholder='Full or part cpy Code o…
# Output()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Company</th>
#       <th>Code</th>
#       <th>Shorted</th>
#       <th>Total</th>
#       <th>Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>FLIGHT CENTRE TRAVEL ORDINARY</td>
#       <td>FLT</td>
#       <td>24903515</td>
#       <td>217957864</td>
#       <td>11.43</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>IDP EDUCATION LTD ORDINARY</td>
#       <td>IEL</td>
#       <td>25731694</td>
#       <td>278336211</td>
#       <td>9.24</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CORE LITHIUM ORDINARY</td>
#       <td>CXO</td>
#       <td>169449639</td>
#       <td>1858516794</td>
#       <td>9.12</td>
#     </tr>
#     <tr>
# ...
